# %%
import pandas as pd
import chromadb
import string
import ast
import os

from nltk.tokenize import word_tokenize
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords
from sentence_transformers import SentenceTransformer
from transformers import T5Tokenizer, T5ForConditionalGeneration

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 1. Análisis exploratorio inicial

# %%
dn = pd.read_csv('../data/raw/Daniel_Noboa.csv')

# %%
dn
# Out:
#        Id     Candidato                                     Temas tratados  \
# 0  DNE001  Daniel Noboa  Formación y trayectoria, Seguridad ciudadana, ...
# 1  DNE002  Daniel Noboa  Seguridad y Justicia; Desaparición de los cuat...
# 2  DNE003  Daniel Noboa  Gobierno y Política; La democracia y sus desaf...
# 3  DNP004  Daniel Noboa  Reducción de la pobreza y la desigualdad; Acce...
# 4  DNP005  Daniel Noboa  Desarrollo Económico Sostenible; Transformació...
# 5  DNP006  Daniel Noboa  Medio Ambiente, Energía y Conectividad; Conser...
# 6  DNP007  Daniel Noboa  Institucionalidad pública; AccÇeso a la inform...
#
#                                          Descripción  \
# 0  La entrevista con el presidente Daniel Noboa a...
# 1  La entrevista con el presidente Daniel Noboa e...
# 2  El conversatorio abordó temas clave como democ...
# 3  El documento presenta un plan integral para el...
# 4  El documento presenta un plan integral para el...
# 5  El documento presenta un enfoque integral para...
# 6  El documento presenta un plan para la **transf...
#
#                                           Entrevista
# 0  Hola a todos Bienvenido a diálogo electoral ug...
# 1  la unidad nacional en pro de la paz y la segur...
# 2  Aló Buenos días con todos por favor tomen asie...
# 3  eguridad, desarrollo y bienestar para todos lo...
# 4  Desarrollo económico sostenible para mejorar l...
# 5  Un Ecuador conectado, preparado para el futuro...
# 6  Un nuevo Estado para un nuevo Ecuador: Eficien...

# %% [markdown]
# ### 2. Preprocesar todo el corpus contenido en 'raw'

# %% [markdown]
# Tenemos dos tareas aquí:
#
# 1. Necesitamos solo archivos .csv, pero tenemos también algunos archivos en formato .xlsx, por lo que debemos primero convertir dichos archivos a .csv para tener un formato universal para nuestro corpus en 'raw'.
# 2. Preprocesar todo el corpus contenido en la carpeta 'raw', y dichos archivos preprocesados guardarlos en otra carpeta 'processed'.

# %%
# Código para encontrar archivos .xlsx y guardarlos como .csv
raw_files = os.scandir('../data/raw')

for file in raw_files:
    if file.name.endswith('.xlsx'):
        df_xlsx = pd.read_excel(f'../data/raw/{file.name}')
        df_xlsx.to_csv(f'../data/raw/{file.name.split(".xlsx")[0]}.csv', index=False)

# %%
# Inicializar el stemmer en español
stemmer = SnowballStemmer("spanish")

# Cargar stopwords en español
stop_words = set(stopwords.words('spanish'))

# Definir caracteres de puntuación adicionales en español
puntuaciones = string.punctuation + "¿¡"

# Función de preprocesamiento mejorada
def preprocesar_texto(texto):
    # Convertir a minúsculas
    texto = texto.lower()

    # Eliminar puntuaciones y números
    texto = "".join([char for char in texto if char not in puntuaciones and not char.isdigit()])

    # Tokenizar
    tokens = word_tokenize(texto)

    # Eliminar stopwords y aplicar stemming
    tokens_procesados = [stemmer.stem(t) for t in tokens if t not in stop_words]

    return " ".join(tokens_procesados)

# %%
# Código para preprocesar todos los archivos .csv de la carpeta 'raw'
csv_files = os.scandir('../data/raw')

for file in csv_files:
    if file.name.endswith('.csv'):
        print(f'Iterando sobre {file.name}')
        df = pd.read_csv(f'../data/raw/{file.name}')
        df['temas_tratados'] = df['temas_tratados'].apply(preprocesar_texto)
        df['descripcion'] = df['descripcion'].apply(preprocesar_texto)
        df['entrevista'] = df['entrevista'].apply(preprocesar_texto)
        df.to_csv(f'../data/processed/{file.name}_processed.csv', index=False)
# Out:
# Iterando sobre Daniel_Noboa.csv
# Iterando sobre entrevistas_carlos_rabascall_combined_final.csv
# Iterando sobre Entrevistas_JimmyJairala.csv
# Iterando sobre Entrevistas_JorgeEscala.csv
# Iterando sobre entrevistas_pedro_granja_combined_final.csv
# Iterando sobre Entrevista_Andrea_Gonzalez.csv
# Iterando sobre Entrevista_LuisaGonzales_JuanCueva.csv
# Iterando sobre FrancescoTabacchi.csv
# Iterando sobre HenryCucalon.csv
# Iterando sobre IvanSaquicela.csv
# Iterando sobre Tilleria-Iza-Kronfle.csv
# Iterando sobre victor_araus.csv
# Iterando sobre Wilson_Gomez.csv

# %% [markdown]
# ### 3. Unificación del corpus

# %% [markdown]
# Tenemos dos carpetas que contienen el corpus:
#
# 1. raw: Contiene los archivos sin procesar del corpus
# 2. processed: Contiene los archivos preprocesados del corpus
#
# Debido a que se ha utilizado lematización al preprocesar el texto, este tiene la característica de recortar palabras, por lo que al recuperar los documentos que queremos no podemos mostrar eso al usuario, es por esto que se hará lo siguiente:
#
# 1. Concatenar todos los archivos de cada carpeta respectivamente, el resultado será dos archivos (raw_corpus.csv y processed_corpus.csv)
# 2. Se realizará un join entre estos dos archivos utilizando la columna 'ID' para esta unión.

# %%
base_dir = r'../data/raw'
processed_files = os.scandir(base_dir)
unified_raw_df = pd.DataFrame()

for file in processed_files:
    if file.name.endswith('.csv'):
        df = pd.read_csv(rf'{base_dir}/{file.name}')
        unified_raw_df = pd.concat([df, unified_raw_df])
    
del df

# %%
base_dir = r'../data/processed'
processed_files = os.scandir(base_dir)
unified_processed_df = pd.DataFrame()

for file in processed_files:
    df = pd.read_csv(rf'{base_dir}/{file.name}')
    unified_processed_df = pd.concat([df, unified_processed_df])

# %%
unified_raw_df['id'] = unified_raw_df['id'].astype(str)
unified_processed_df['id'] = unified_processed_df['id'].astype(str)

# %%
unified_global_df = pd.merge(unified_raw_df, unified_processed_df, on='id', suffixes=('_raw', '_pre'))

# %%
unified_global_df.drop(columns = ['descripcion_pre', 'temas_tratados_pre', 'candidato_pre'], inplace=True)
unified_global_df.head(10)
# Out:
#        id candidato_raw                                 temas_tratados_raw  \
# 0  WGE001  Wilson Gomez  Conformación del binomio presidencial; Relació...
# 1  WGE002  Wilson Gomez  Crisis del país; Propuestas de rescate y trans...
# 2  WGE003  Wilson Gomez  La necesidad de un cambio en el modelo educati...
# 3  WGP004  Wilson Gomez  El rol de la agricultura, la pesca y la indust...
# 4  WGP005  Wilson Gomez  Extracción de petróleo; Historia y auge de la ...
# 5  WGP006  Wilson Gomez  Definición y módulos de FinTech; Criptomonedas...
# 6  WGP007  Wilson Gomez  Economía agraria; Industrialización y auge pet...
# 7  WGP008  Wilson Gomez  Ecoturismo en Ecuador; Economía y Productivida...
# 8     VA1  Victor Araus  Retiro de la visa de Víctor Araus, conspiració...
# 9     VA2  Victor Araus  Seguridad y combate a la delincuencia, elimina...
#
#                                      descripcion_raw  \
# 0  El documento es una entrevista en la que un ca...
# 1  El documento expone la visión y propuestas del...
# 2  El documento es una entrevista con el candidat...
# 3  El documento analiza el sector agropecuario y ...
# 4  El documento analiza tres sectores clave en Ec...
# 5  El documento analiza el sector FinTech, su imp...
# 6  El texto describe la evolución económica de Ec...
# 7  El documento propone un plan de desarrollo par...
# 8  La primera entrevista se centró en sus propues...
# 9  En esta entrevista, Víctor Araus presentó su v...
#
#                                       entrevista_raw  \
# 0  Yo vengo trabajando para muchos presidentes he...
# 1  Buenos días nos encontramos con Wilson Gómez c...
# 2  un gran abrazo para la inmensa audiencia de ra...
# 3  Parte 1: Diagnóstico de la Situación Actual La...
# 4  Parte 1: Extracción de petróleo en Ecuador Dia...
# 5  Parte 1: ¿Qué es FinTech y cuáles son sus módu...
# 6  EXTRACCIÓN DE ECONOMÍA & PRODUCTIVIDAD Histori...
# 7  Estrategia para el Desarrollo del Ecoturismo e...
# 8  Buenos días gracias por acompañarnos Gracias a...
# 9  de la mañana con 55 minutos le vamos a dar la ...
#
#                                       entrevista_pre
# 0  veng trabaj president oportun serv voluntari e...
# 1  buen dias encontr wilson gomez candidat presid...
# 2  gran abraz inmens audienci radi moren ecuador ...
# 3  part diagnost situacion actual agricultur pesc...
# 4  part extraccion petrole ecuador diagnost situa...
# 5  part fintech cual modul principal termin finte...
# 6  extraccion econom product histori econom ecuad...
# 7  estrategi desarroll ecotur ecuador problem afe...
# 8  buen dias graci acompañ graci usted invit salu...
# 9  mañan minut vam dar bienven general victor ara...

# %%
unified_raw_df.to_csv(rf'../data/raw/raw_corpus.csv', index=False)
unified_processed_df.to_csv(rf'../data/processed/processed_corpus.csv', index=False)
unified_global_df.to_csv(rf'../data/embeddings/unified_corpus.csv', index=False)

# %% [markdown]
# ### 4. Generación de embeddings

# %% [markdown]
# Una vez tenemos todo el corpus unificado en un único archivo, tenemos que calcular los embeddings para el contenido de cada entrevista, esto lo haremos utilizando la libreria SentenceTransformer.

# %%
unified_corpus = pd.read_csv('../data/embeddings/unified_corpus.csv')

# %%
# Modelo con el que vamos a generar embeddings
modelo = SentenceTransformer("all-MiniLM-L6-v2")

# Generación de los embeddings a partir de corpus preprocesado
unified_corpus['embedding_entrevista'] = unified_corpus['entrevista_pre'].apply(lambda x: modelo.encode(x).tolist())

# %%
unified_corpus['embedding_entrevista']
# Out:
# 0     [-0.014551389962434769, -0.0037382026202976704...
# 1     [0.007717538625001907, -0.04105502739548683, -...
# 2     [-0.007631767075508833, -0.03830636292695999, ...
# 3     [0.01490846835076809, -0.08086168766021729, -0...
# 4     [0.013256512582302094, -0.06549493223428726, -...
# 5     [-0.008189497515559196, -0.02202538400888443, ...
# 6     [0.020869851112365723, -0.09945572167634964, 0...
# 7     [0.06572176516056061, -0.0940171629190445, -0....
# 8     [-0.02826605550944805, 0.026913078501820564, -...
# 9     [-0.041109848767519, -0.02618183009326458, 0.0...
# 10    [-0.03815913945436478, 0.0021859726402908564, ...
# 11    [0.02806268073618412, -0.021873988211154938, -...
# 12    [0.0787014365196228, -0.07890287786722183, -0....
# 13    [0.04036758840084076, -0.09257502853870392, -0...
# 14    [0.012605945579707623, 0.02397148311138153, -0...
# 15    [0.0333082340657711, -0.0050742304883897305, -...
# 16    [0.006792896892875433, -0.019541403278708458, ...
# 17    [-0.0605597123503685, 0.013441740535199642, 0....
# 18    [-0.009193109348416328, -0.020491592586040497,...
# 19    [0.00980434287339449, 0.0011027348227798939, -...
# 20    [-0.015661271288990974, 0.02526126056909561, -...
# 21    [0.003044733079150319, 0.05651490390300751, 0....
# 22    [-0.008701181970536709, -0.026396574452519417,...
# 23    [-0.016657115891575813, -0.02523769624531269, ...
# 24    [-0.024191945791244507, -0.0052997334860265255...
# 25    [-0.06798649579286575, 0.00024035155365709215,...
# 26    [-0.05305613577365875, 0.04736487567424774, 0....
# 27    [-0.05404848977923393, 0.014158657751977444, -...
# 28    [0.02224121242761612, 0.014776787720620632, -0...
# 29    [0.019818801432847977, 0.0015925888437777758, ...
# 30    [0.002789351623505354, 0.03614955022931099, -0...
# 31    [-0.034997545182704926, -0.035473987460136414,...
# 32    [0.013894897885620594, -0.04698892682790756, 0...
# 33    [-0.028828460723161697, -0.06882455945014954, ...
# 34    [0.0372387170791626, 0.014369295910000801, -0....
# 35    [0.04751041904091835, 0.023275144398212433, -0...
# 36    [-0.022272203117609024, 0.00520999263972044, -...
# 37    [0.0378565788269043, -0.042687416076660156, 0....
# 38    [0.030315641313791275, 0.04667812958359718, 0....
# 39    [-0.05781462788581848, -0.0021904869936406612,...
# 40    [-0.030499383807182312, 0.08324316143989563, -...
# 41    [-0.007611376233398914, 0.002722405595704913, ...
# 42    [-0.01823127642273903, 0.011728652752935886, -...
# 43    [-0.026966692879796028, -0.036252960562705994,...
# 44    [-0.023522600531578064, -0.0028098414186388254...
# 45    [-0.008040785789489746, 0.0018243828089907765,...
# 46    [-0.004995743278414011, 0.013680746778845787, ...
# 47    [-0.004524907562881708, -0.031198782846331596,...
# 48    [-0.013575139455497265, -0.039985641837120056,...
# 49    [0.006839875131845474, -0.03802037984132767, 0...
# 50    [0.016809863969683647, -0.010982906445860863, ...
# 51    [-0.05267263576388359, 0.05301240086555481, -0...
# 52    [0.011799047701060772, -0.05923914164304733, -...
# 53    [-0.0010314254323020577, -0.06436630338430405,...
# 54    [0.08150909096002579, -0.052145641297101974, 0...
# 55    [0.029494814574718475, -0.025782305747270584, ...
# Name: embedding_entrevista, dtype: object

# %%
unified_corpus.to_csv(rf'../data/embeddings/unified_corpus_embeddings.csv', index=False)

# %% [markdown]
# ### 5. Base de datos vectorial con ChromaDB

# %% [markdown]
# Una vez tenemos un único archivo que contiene todo el corpus junto a los embeddings del contenido de cada entrevista, vamos a construir una base de datos vectorial con ChromaDB para la realización de consultas.
#
# La estructura a manejar será la siguiente:
# - ID: El identificador alfanumérico de cada entrevista
# - embeddings: El vector representativo del contenido de la entrevista
# - metadatos: El nombre del candidato, tema tratado y una descripción de la entrevista

# %%
# Creación de la base de datos vectorial
chroma_client = chromadb.PersistentClient(path="../db/")
collection = chroma_client.get_or_create_collection("entrevistas")

# %%
embeddings_df = pd.read_csv('../data/embeddings/unified_corpus_embeddings.csv')

# %%
embeddings_df['embedding_entrevista']
# Out:
# 0     [-0.014551389962434769, -0.0037382026202976704...
# 1     [0.007717538625001907, -0.04105502739548683, -...
# 2     [-0.007631767075508833, -0.03830636292695999, ...
# 3     [0.01490846835076809, -0.08086168766021729, -0...
# 4     [0.013256512582302094, -0.06549493223428726, -...
# 5     [-0.008189497515559196, -0.02202538400888443, ...
# 6     [0.020869851112365723, -0.09945572167634964, 0...
# 7     [0.06572176516056061, -0.0940171629190445, -0....
# 8     [-0.02826605550944805, 0.026913078501820564, -...
# 9     [-0.041109848767519, -0.02618183009326458, 0.0...
# 10    [-0.03815913945436478, 0.0021859726402908564, ...
# 11    [0.02806268073618412, -0.021873988211154938, -...
# 12    [0.0787014365196228, -0.07890287786722183, -0....
# 13    [0.04036758840084076, -0.09257502853870392, -0...
# 14    [0.012605945579707623, 0.02397148311138153, -0...
# 15    [0.0333082340657711, -0.0050742304883897305, -...
# 16    [0.006792896892875433, -0.019541403278708458, ...
# 17    [-0.0605597123503685, 0.013441740535199642, 0....
# 18    [-0.009193109348416328, -0.020491592586040497,...
# 19    [0.00980434287339449, 0.0011027348227798939, -...
# 20    [-0.015661271288990974, 0.02526126056909561, -...
# 21    [0.003044733079150319, 0.05651490390300751, 0....
# 22    [-0.008701181970536709, -0.026396574452519417,...
# 23    [-0.016657115891575813, -0.02523769624531269, ...
# 24    [-0.024191945791244507, -0.0052997334860265255...
# 25    [-0.06798649579286575, 0.00024035155365709215,...
# 26    [-0.05305613577365875, 0.04736487567424774, 0....
# 27    [-0.05404848977923393, 0.014158657751977444, -...
# 28    [0.02224121242761612, 0.014776787720620632, -0...
# 29    [0.019818801432847977, 0.0015925888437777758, ...
# 30    [0.002789351623505354, 0.03614955022931099, -0...
# 31    [-0.034997545182704926, -0.035473987460136414,...
# 32    [0.013894897885620594, -0.04698892682790756, 0...
# 33    [-0.028828460723161697, -0.06882455945014954, ...
# 34    [0.0372387170791626, 0.014369295910000801, -0....
# 35    [0.04751041904091835, 0.023275144398212433, -0...
# 36    [-0.022272203117609024, 0.00520999263972044, -...
# 37    [0.0378565788269043, -0.042687416076660156, 0....
# 38    [0.030315641313791275, 0.04667812958359718, 0....
# 39    [-0.05781462788581848, -0.0021904869936406612,...
# 40    [-0.030499383807182312, 0.08324316143989563, -...
# 41    [-0.007611376233398914, 0.002722405595704913, ...
# 42    [-0.01823127642273903, 0.011728652752935886, -...
# 43    [-0.026966692879796028, -0.036252960562705994,...
# 44    [-0.023522600531578064, -0.0028098414186388254...
# 45    [-0.008040785789489746, 0.0018243828089907765,...
# 46    [-0.004995743278414011, 0.013680746778845787, ...
# 47    [-0.004524907562881708, -0.031198782846331596,...
# 48    [-0.013575139455497265, -0.039985641837120056,...
# 49    [0.006839875131845474, -0.03802037984132767, 0...
# 50    [0.016809863969683647, -0.010982906445860863, ...
# 51    [-0.05267263576388359, 0.05301240086555481, -0...
# 52    [0.011799047701060772, -0.05923914164304733, -...
# 53    [-0.0010314254323020577, -0.06436630338430405,...
# 54    [0.08150909096002579, -0.052145641297101974, 0...
# 55    [0.029494814574718475, -0.025782305747270584, ...
# Name: embedding_entrevista, dtype: object

# %%
for index, row in embeddings_df.iterrows():
    collection.add(
        ids = [row['id']],
        documents = [row['entrevista_raw']],
        embeddings = [ast.literal_eval(row['embedding_entrevista'])],
        metadatas = [{
            'candidato': row['candidato_raw'],
            'temas_tratados': row['temas_tratados_raw'],
            'descripcion': row['descripcion_raw']
        }]
    )

# %% [markdown]
# ### 6. Ejemplo de consultas

# %%
query = 'Vamos a reducir los asaltos en el país'

# Preprocesar la consulta
preproc_query = preprocesar_texto(query)

# Generar el embedding de la consulta
embedding_query = modelo.encode(preproc_query)

# %%
# Realizar la consulta en la base de datos
resultados = collection.query(query_embeddings=[embedding_query], n_results=3)  # Los 3 resultados más cercanos

# Mostrar los resultados
print("Resultados de la consulta:")
print()
for i in range(len(resultados['documents'][0])):
    print(f"Resultado {i+1}")
    print(f"ID: {resultados['ids'][0][i]}")
    print(f"Contenido: {resultados['documents'][0][i]}")
    print(f"Metadatos: {resultados['metadatas'][0][i]}")
    print("")
# Out:
# Resultados de la consulta:
#
# Resultado 1
# ID: FT3
# Contenido:  ¿Qué es lo que es la historia del país? ¿Qué es el país del país del país? ¿Qué es el país del país del país del país del país? ¿Qué es el país del país del país del país del país? La misma pregunta me hace mi familia, mi esposa, mis hijos, mis padres, me hacen mis socios. Y este país ha sido muy generoso conmigo. Me he caído, me he levantado. Pero, afinitivamente, este país ha sido bueno conmigo. Víe el momento y la forma de retribuírselo. Creo en mi país, creo en el Ecuador. Porque ahora, si bien usted ha estado ligado a las partes ganaderas, productivas, a la parte del agro, al momento de ingresar a la vida política, ¿qué le...? ¿Cómo soles interés? No solo por ingresar, sino por mantenerse ahí. Porque después, eso pasó como gobernador, tuvo una candidatura de refectura también, ahora salta la presidencia. ¿A qué se debe este interés en seguir viendo también que es una dinámica muy distinta a la que a lo mejor estaba acostumbrada previamente? Quizás después de ser gobernador, me tomé unos cuantos meses de descanso. Estuve bien comprometido con mi provincia y con mi país. Luego de eso decidí aceptar. Aceptar este reto, me lo proponen el gremio de los pueblos montubios, los agricultores, los productores, los ganaderos. Y uno nunca sabe cuándo te llega el momento de aceptar. Lo acepté. Y es un desafío que tengo, es un reto. Y quienes me conocen saben que no voy a bajar los brazos hasta lograrlo. Quizás de política no les puedo hablar mucho porque no soy muy político. Soy seguramente el productor, soy seguramente el emprendedor que nunca desiste, que está aquí frente a ustedes. Alejandro. ¿Cómo fue la designación para que usted vaya por la presidencia tomando en cuenta que el movimiento salía de la muerte cruzada? Habría estos problemas con Esteban Bernal, que quería ser candidato. ¿Cómo llega usted a ser designado y cómo funcionó ese proceso interno del movimiento? Porque estamos acostumbrados en el país a que el caudillo de cada movimiento diga que esto es mi candidato y esta persona quiero que sea el candidato. En el caso de Creo, ¿cómo fue esto? Mire, por favor dígame Francesco. Quizás yo soy el candidato natural de Creo. Como hice Gonzalo, ya lo fui mientras a la prefectura del Guayas. Luego fui gobernador hasta el último día del gobierno pasado. Y una semana antes que recibo esta propuesta por parte de los pueblos montubios y algunos gremios productivos, decido aceptarla. Tal vez algunas horas antes, no sé si tres días antes, cuatro días antes de que se acabaran los plazos. Y el movimiento Creo hace sus primarias, hace su movimiento democrático interno del cual no participé. Y me acepta. Me diría que yo me autopropuse. Fue una autopropuesta. Y aquí estoy. Aquí estoy hoy en día y más allá de pensar en un movimiento político o de inclinaciones políticas, estoy pensando en cómo voy a sacar al país adelante y de manera distinta como se lo ha tratado de sacar. Tengo claro que si seguimos haciendo lo mismo las cosas además van a cambiar. Y en este caso que usted dice que es el candidato natural de Creo, y usted dice que no le gusta hablar mucho de política pero lo estamos haciendo en este momento. ¿Cuál es la representación ideológica de Creo y por qué dice usted ser el candidato natural de este movimiento? Primero porque ya fui candidato. Ya fui gobernador del Guayas hasta el último día seguramente porque no me cambio de camisa, no le hago al camisetazo. Tengo el mismo reloj, el mismo número celular y la misma esposa desde hace 26 años. ¿Y cuál es la inclinación de Creo? Lo único que le puedo contestar es que es 100% democrática. También le puedo contestar sin que me lo pregunte que no existe un solo afiliado que esté envuelto en algún caso de corrupción. Para mí eso es bastante y eso es lo que le puedo contestar al respecto. El presidente Lazo propuso durante su gestión algunas reformas a la Constitución, unas le fueron aceptadas, unas la pudo llevar a cabo, otras no. ¿Usted cómo se vería manejando el país con una ...
# Metadatos: {'candidato': 'Francesco Tabacchi', 'descripcion': 'Francesco Tabaqui, candidato presidencial por Creo, expone su visión para el país basada en seguridad, generación de empleo y apertura a la inversión privada en sectores estratégicos como energía, minería y petróleo. Propone una política de "mano dura, mano justa y mano inteligente", inspirada en el modelo de El Salvador, con la creación del Escuadrón de la Pacificación para combatir el crimen organizado. En economía, plantea incentivos fiscales para fomentar el empleo y la modernización del sector agropecuario con una "agricultura 4.0". Rechaza la idea de modificar la Constitución y en su lugar aboga por reformas rápidas para mejorar la seguridad y la economía. También sugiere concesionar la generación eléctrica e infraestructura vial, y se muestra abierto a revisar el sistema de subsidios. En política exterior, busca mantener relaciones pragmáticas con EE.UU., México y Venezuela, aunque sin reconocer a Nicolás Maduro. Destaca la importancia de la transparencia y asegura que su campaña se financia con recursos propios y redes sociales, enfatizando su historial como empresario y gobernador del Guayas.', 'temas_tratados': 'reforma constitucional, cambios legislativos, seguridad, crimen organizado, influencia del modelo de El Salvador, Escuadrón de la Pacificación, relación con la Asamblea Nacional, bloqueos legislativos, administración pública, compras del Estado (CERCOP), crisis del IESS, generación de empleo, incentivos fiscales para contratación, infraestructura, concesiones viales, crisis energética, inversión extranjera, política exterior, relaciones con México, relaciones con Venezuela, relaciones con EE.UU., subsidios de combustibles, tarifas eléctricas, financiamiento de campaña, transparencia patrimonial'}
#
# Resultado 2
# ID: HC2
# Contenido:  ¿Cuál es tu opinión? ¡Nos vemos! ¡Nos vemos! ¡Nos vemos! ¡Nos vemos! ¡Nos vemos! ¡Nos vemos! ¡Nos vemos! La misma pregunta me la hace mi familia, mi esposa, mis hijos, mis padres me la hacen mis socios y este país ha sido muy generoso conmigo me he caído, me he levantado pero, afinalmente este país ha sido bueno conmigo y es el momento y la forma de retribuírselo creo en mi país, creo en el Ecuador ¿Por qué? Ahora, si bien usted ha estado ligado a las partes ganaderas, productivas, a la parte del agro al momento de ingresar a la vida política quiere como suele ser interés no solo por ingresar sino por mantenerse ahí porque después eso pasó como gobernador y luego una candidatura de la prefectura también ahora salte la presidencia, ¿a qué se debe este interés en seguir? viendo también que es una dinámica muy distinta a la que a lo mejor estaba acostumbrado previamente Quizás después de ser gobernador me tomé unos cuantos meses de descanso, estuve bien comprometido con mi provincia y con mi país luego de eso decidí aceptar, aceptar este reto me lo proponen el gremio los pueblos montubios, los agricultores los productores, los ganaderos y uno nunca sabe cuando te llega el momento de aceptar lo acepté y es un desafío que tengo es un reto y quienes me conocen saben que no voy a bajar los brazos hasta lograrlo quizás de política no les puedo hablar mucho porque no soy muy político soy seguramente el productor soy seguramente el emprendedor que nunca desiste que está aquí frente a ustedes Alejandro candidato, ¿cómo fue la designación para que usted vaya por la presidencia tomando en cuenta que el movimiento salía de la muerte cruzada habría estos problemas con Esteban Bernal que quería ser candidato ¿cómo llega usted a ser designado y cómo funcionó ese proceso interno del movimiento porque estamos acostumbrados en el país a que el caudillo de cada movimiento diga esto es mi candidato y esta persona quiero que sea el candidato, en el caso de creo ¿cómo fue esto? mire, por favor dígame Francesco quizás yo soy el candidato natural de creo ya lo fui mientras a la prefectura del Guayas luego fui gobernador hasta el último día del gobierno pasado y una semana antes que recibo esta propuesta por parte de los pueblos Montubios y algunos gremios productivos decido aceptarla tal vez algunas horas antes, no sé si 3 días antes 4 días antes de que se acabaran los plazos y el movimiento creo hace sus primarias hace su movimiento democrático interno del cual no participé y y me acepta diría que yo me autopropuse fue una autopropuesta y aquí estoy aquí estoy hoy en día y más allá de pensar en un movimiento político o de inclinaciones políticas y estoy pensando en cómo voy a sacar al país adelante y de manera distinta como se lo ha tratado de sacar tengo claro que si seguimos haciendo lo mismo las cosas van a cambiar y en este caso que usted dice que es el candidato natural de creo y usted dice que no le gusta hablar mucho de política pero lo estamos haciendo en este momento ¿cuál es la la representación ideológica de creo? y por qué dice usted que no quiere ser el candidato natural de este movimiento primero porque ya fui candidato ya fui gobernador del guayas hasta el último día seguramente porque no me cambio de camisa no le hago al camisetazo tengo el mismo reloj, el mismo número celular y la misma esposa desde hace 26 años y ¿cuál es la inclinación de creo lo único que le puedo contestar es que es 100% democrática también le puedo contestar sin que me lo pregunte que no existe un sólo afiliado que esté envuelto en algún caso de corrupción para mí eso es bastante y eso es lo que le puedo contestar al respecto el presidente lazo propuso durante su reunión algunas reformas a la constitución, unas le fueron aceptadas una la pudo llevar a cabo tras no usted como cómo se vería manejando el país con una constitución heredada de un gobierno al que ustedes critican mucho qué cambios podría proponer perdón ¿a cuál gobierno se refiere y quiénes ...
# Metadatos: {'candidato': 'Henry Cucalon', 'descripcion': 'Henry Cucalón, candidato presidencial de las elecciones de 2025, quien expone sus propuestas para el país, enfocándose en la liberalización de sectores como la minería y la energía, la simplificación de trámites y la reducción de la burocracia. Cucalón destaca la importancia de un estado austero y eficiente, criticando el populismo y la corrupción. También aborda temas clave como la seguridad, la reforma laboral, la creación de empleo y la modernización del sistema penitenciario, buscando un cambio radical hacia un gobierno más enfocado en la iniciativa privada y en políticas de largo plazo para el desarrollo económico.', 'temas_tratados': 'propuestas de inversión privada, sistema judicial, formalidad en la política, seguridad, empleo, minería, agricultura, turismo, austeridad fiscal, subsidios, generación de empleo, régimen laboral, reformas penitenciarias, reducción de burocracia'}
#
# Resultado 3
# ID: VA2
# Contenido: de la mañana con 55 minutos le vamos a dar la bienvenida al general Víctor araus candidato a la presidencia por el movimiento pueblo igualdad y democracia lista 4atro vamos a conversar con él sobre su plan de trabajo sobre el debate presidencial y sobre lo que él propone como candidato Y por qué hay que darle el voto bienvenido general Víctor arus a la cabina de wq noticias estamos siendo escuchados por el dí al 102,1 FM como también nos están escuchando por todas nuestras redes sociales a nivel naci Gracias por estar con nosotros Por qué hay que votar por vítor gracias a usted por la invitación Paul gracias a Luis Antonio porque hay quear porque soy la única opción pues Paul antes la entrevista le decía yo soy el único que puede devolverle la paz y la tranquilidad al Ecuador sin seguridad no hay nada Paul estos 4 años hay que recuperar la paz que los Ecuatorianos necesitan para que haya reactivación económica para que haya empleo para que puedan vivir en paz para que todo surja de la mejor manera pero sin seguridad no hay nada Paul para reactivar el turismo para reactivar muchas fuentes de ingreso que por el hecho de haber sido catalogados como narcoestado y por haber sido vistos internacionalmente como un país inseguro por tener y hay que cambiar esa imagen de tener la ciudad más peligrosa de la región o del mundo para cambiar esaa realidad que el momento hay 658 asesinatos solo en el mes de enero que este paso Vamos a superar los 8000 y que la tasa va a subir considerablemente por eso yo quiero ser presidente para devolverle a usted Paul a sus hijos a su hermanos a sus familiares a las personas de la tercera edad ese país de paz que todos necesitan correcto dentro de sus planes qué le promete al público para que le dé su voto a ver yo no prometo yo son propuestas que hago que las voy a cumplir porque yo demagogo no soy demagogo es ofrecer y no cumplir Y peor aú traicionar jamás Paul soy un general de honor por eso llevo esta chaqueta que representa el espíritu y la esencia de Víctor araus un general de honor que cumple lo que dice entonces dentro de mi propuesta está dev volver integralmente integralmente la paz y la seguridad de los ciudadanos cómo le voy a hacer eso Paul ya lo he dicho públicamente le voy a quitar los derechos a los delincuentes De qué forma voy a tratar al delincuente tal cual como trata al ciudadano Paul si el ciudadano quita la vida a un a un ciudadano común se merece la vida es obligación del Estado Paul acabar con la vida del delincuente antes que el delincuente acabe con el ciudadano de bien pero aquí en nuestro país nadie le puede quitarle la vida a nadie nadie y los delincuentes Por qué le quitan la vida a ver yo no que le voy a quitar la vida Voy a someter al la pena de muerte porque yo voy a ser pero es complicado el tema de la pena de muerte en nuestro país hay que cambiar muchas cosas a ver Paul usted no se convierta con todo respeto amigo lo conocemos años no se convierta en una persona que busca un problema o una solución la solución la estoy planteando yo pues Paul si no nos cruzamos de brazo pa me explico entonces una solución para acabar con el sicariato y las violaciones es liberar al Ecuador porque no es que yo los voy a matar No es que la policía los va a matar pero delincuente armado que pong en riesgo la vida de un ciudadano la suya le esperará el cementerio porque la policía tendrá todo el respaldo y no tendrá miedo de darle bala al delincuente Entonces el tema de los los picaros y violaciones voy a luchar incansablemente para liberar al Ecuador de los tratados internacionales porque no soy insensato Pues yo no voy a exponer al país Paul a sanciones internacionales sanciones diplomáticas y una serie de situaciones que en vez de ayudar van a debilitar la imagen del país pero el momento que yo proponga a nivel de organismos internacionales liberar al Ecuador Para proponer la pena de muerte y esa pena de muerte sea bien aplicada Paul porque por ahí también aparece pero Cómo  ...
# Metadatos: {'candidato': 'Victor Araus', 'descripcion': 'En esta entrevista, Víctor Araus presentó su visión sobre seguridad y justicia, reafirmando su propuesta de eliminar los derechos de los delincuentes y considerar la implementación de la pena de muerte mediante consulta popular. Señaló la necesidad de declarar una crisis carcelaria y tomar control de las cárceles, promoviendo la rehabilitación de presos mediante trabajo y educación obligatoria. Araus también enfatizó su compromiso de luchar contra la corrupción en la justicia y mejorar la seguridad pública. Además, destacó planes económicos como la reactivación de empleo y el combate a la evasión tributaria, posicionándose como el único candidato con un enfoque firme y disruptivo para devolver la paz al Ecuador.', 'temas_tratados': 'Seguridad y combate a la delincuencia, eliminación de derechos a los delincuentes, propuestas para implementar la pena de muerte, crisis carcelaria y control de las cárceles, trabajo y educación obligatoria para presos, consulta popular para reformas legales, migración y deportación de extranjeros ilegales, reactivación económica, generación de empleo, combate a la evasión tributaria, corrupción en el sistema judicial, liderazgo en la seguridad pública.'}

# %%
resultados["documents"][0]
# Out:
# [' ¿Qué es lo que es la historia del país? ¿Qué es el país del país del país? ¿Qué es el país del país del país del país del país? ¿Qué es el país del país del país del país del país? La misma pregunta me hace mi familia, mi esposa, mis hijos, mis padres, me hacen mis socios. Y este país ha sido muy generoso conmigo. Me he caído, me he levantado. Pero, afinitivamente, este país ha sido bueno conmigo. Víe el momento y la forma de retribuírselo. Creo en mi país, creo en el Ecuador. Porque ahora, si bien usted ha estado ligado a las partes ganaderas, productivas, a la parte del agro, al momento de ingresar a la vida política, ¿qué le...? ¿Cómo soles interés? No solo por ingresar, sino por mantenerse ahí. Porque después, eso pasó como gobernador, tuvo una candidatura de refectura también, ahora salta la presidencia. ¿A qué se debe este interés en seguir viendo también que es una dinámica muy distinta a la que a lo mejor estaba acostumbrada previamente? Quizás después de ser gobernador, me tomé unos cuantos meses de descanso. Estuve bien comprometido con mi provincia y con mi país. Luego de eso decidí aceptar. Aceptar este reto, me lo proponen el gremio de los pueblos montubios, los agricultores, los productores, los ganaderos. Y uno nunca sabe cuándo te llega el momento de aceptar. Lo acepté. Y es un desafío que tengo, es un reto. Y quienes me conocen saben que no voy a bajar los brazos hasta lograrlo. Quizás de política no les puedo hablar mucho porque no soy muy político. Soy seguramente el productor, soy seguramente el emprendedor que nunca desiste, que está aquí frente a ustedes. Alejandro. ¿Cómo fue la designación para que usted vaya por la presidencia tomando en cuenta que el movimiento salía de la muerte cruzada? Habría estos problemas con Esteban Bernal, que quería ser candidato. ¿Cómo llega usted a ser designado y cómo funcionó ese proceso interno del movimiento? Porque estamos acostumbrados en el país a que el caudillo de cada movimiento diga que esto es mi candidato y esta persona quiero que sea el candidato. En el caso de Creo, ¿cómo fue esto? Mire, por favor dígame Francesco. Quizás yo soy el candidato natural de Creo. Como hice Gonzalo, ya lo fui mientras a la prefectura del Guayas. Luego fui gobernador hasta el último día del gobierno pasado. Y una semana antes que recibo esta propuesta por parte de los pueblos montubios y algunos gremios productivos, decido aceptarla. Tal vez algunas horas antes, no sé si tres días antes, cuatro días antes de que se acabaran los plazos. Y el movimiento Creo hace sus primarias, hace su movimiento democrático interno del cual no participé. Y me acepta. Me diría que yo me autopropuse. Fue una autopropuesta. Y aquí estoy. Aquí estoy hoy en día y más allá de pensar en un movimiento político o de inclinaciones políticas, estoy pensando en cómo voy a sacar al país adelante y de manera distinta como se lo ha tratado de sacar. Tengo claro que si seguimos haciendo lo mismo las cosas además van a cambiar. Y en este caso que usted dice que es el candidato natural de Creo, y usted dice que no le gusta hablar mucho de política pero lo estamos haciendo en este momento. ¿Cuál es la representación ideológica de Creo y por qué dice usted ser el candidato natural de este movimiento? Primero porque ya fui candidato. Ya fui gobernador del Guayas hasta el último día seguramente porque no me cambio de camisa, no le hago al camisetazo. Tengo el mismo reloj, el mismo número celular y la misma esposa desde hace 26 años. ¿Y cuál es la inclinación de Creo? Lo único que le puedo contestar es que es 100% democrática. También le puedo contestar sin que me lo pregunte que no existe un solo afiliado que esté envuelto en algún caso de corrupción. Para mí eso es bastante y eso es lo que le puedo contestar al respecto. El presidente Lazo propuso durante su gestión algunas reformas a la Constitución, unas le fueron aceptadas, unas la pudo llevar a cabo, otras no. ¿Usted cómo se vería manejando el país con una Constitu ...
#  ' ¿Cuál es tu opinión? ¡Nos vemos! ¡Nos vemos! ¡Nos vemos! ¡Nos vemos! ¡Nos vemos! ¡Nos vemos! ¡Nos vemos! La misma pregunta me la hace mi familia, mi esposa, mis hijos, mis padres me la hacen mis socios y este país ha sido muy generoso conmigo me he caído, me he levantado pero, afinalmente este país ha sido bueno conmigo y es el momento y la forma de retribuírselo creo en mi país, creo en el Ecuador ¿Por qué? Ahora, si bien usted ha estado ligado a las partes ganaderas, productivas, a la parte del agro al momento de ingresar a la vida política quiere como suele ser interés no solo por ingresar sino por mantenerse ahí porque después eso pasó como gobernador y luego una candidatura de la prefectura también ahora salte la presidencia, ¿a qué se debe este interés en seguir? viendo también que es una dinámica muy distinta a la que a lo mejor estaba acostumbrado previamente Quizás después de ser gobernador me tomé unos cuantos meses de descanso, estuve bien comprometido con mi provincia y con mi país luego de eso decidí aceptar, aceptar este reto me lo proponen el gremio los pueblos montubios, los agricultores los productores, los ganaderos y uno nunca sabe cuando te llega el momento de aceptar lo acepté y es un desafío que tengo es un reto y quienes me conocen saben que no voy a bajar los brazos hasta lograrlo quizás de política no les puedo hablar mucho porque no soy muy político soy seguramente el productor soy seguramente el emprendedor que nunca desiste que está aquí frente a ustedes Alejandro candidato, ¿cómo fue la designación para que usted vaya por la presidencia tomando en cuenta que el movimiento salía de la muerte cruzada habría estos problemas con Esteban Bernal que quería ser candidato ¿cómo llega usted a ser designado y cómo funcionó ese proceso interno del movimiento porque estamos acostumbrados en el país a que el caudillo de cada movimiento diga esto es mi candidato y esta persona quiero que sea el candidato, en el caso de creo ¿cómo fue esto? mire, por favor dígame Francesco quizás yo soy el candidato natural de creo ya lo fui mientras a la prefectura del Guayas luego fui gobernador hasta el último día del gobierno pasado y una semana antes que recibo esta propuesta por parte de los pueblos Montubios y algunos gremios productivos decido aceptarla tal vez algunas horas antes, no sé si 3 días antes 4 días antes de que se acabaran los plazos y el movimiento creo hace sus primarias hace su movimiento democrático interno del cual no participé y y me acepta diría que yo me autopropuse fue una autopropuesta y aquí estoy aquí estoy hoy en día y más allá de pensar en un movimiento político o de inclinaciones políticas y estoy pensando en cómo voy a sacar al país adelante y de manera distinta como se lo ha tratado de sacar tengo claro que si seguimos haciendo lo mismo las cosas van a cambiar y en este caso que usted dice que es el candidato natural de creo y usted dice que no le gusta hablar mucho de política pero lo estamos haciendo en este momento ¿cuál es la la representación ideológica de creo? y por qué dice usted que no quiere ser el candidato natural de este movimiento primero porque ya fui candidato ya fui gobernador del guayas hasta el último día seguramente porque no me cambio de camisa no le hago al camisetazo tengo el mismo reloj, el mismo número celular y la misma esposa desde hace 26 años y ¿cuál es la inclinación de creo lo único que le puedo contestar es que es 100% democrática también le puedo contestar sin que me lo pregunte que no existe un sólo afiliado que esté envuelto en algún caso de corrupción para mí eso es bastante y eso es lo que le puedo contestar al respecto el presidente lazo propuso durante su reunión algunas reformas a la constitución, unas le fueron aceptadas una la pudo llevar a cabo tras no usted como cómo se vería manejando el país con una constitución heredada de un gobierno al que ustedes critican mucho qué cambios podría proponer perdón ¿a cuál gobierno se refiere y quiénes son uste ...
#  'de la mañana con 55 minutos le vamos a dar la bienvenida al general Víctor araus candidato a la presidencia por el movimiento pueblo igualdad y democracia lista 4atro vamos a conversar con él sobre su plan de trabajo sobre el debate presidencial y sobre lo que él propone como candidato Y por qué hay que darle el voto bienvenido general Víctor arus a la cabina de wq noticias estamos siendo escuchados por el dí al 102,1 FM como también nos están escuchando por todas nuestras redes sociales a nivel naci Gracias por estar con nosotros Por qué hay que votar por vítor gracias a usted por la invitación Paul gracias a Luis Antonio porque hay quear porque soy la única opción pues Paul antes la entrevista le decía yo soy el único que puede devolverle la paz y la tranquilidad al Ecuador sin seguridad no hay nada Paul estos 4 años hay que recuperar la paz que los Ecuatorianos necesitan para que haya reactivación económica para que haya empleo para que puedan vivir en paz para que todo surja de la mejor manera pero sin seguridad no hay nada Paul para reactivar el turismo para reactivar muchas fuentes de ingreso que por el hecho de haber sido catalogados como narcoestado y por haber sido vistos internacionalmente como un país inseguro por tener y hay que cambiar esa imagen de tener la ciudad más peligrosa de la región o del mundo para cambiar esaa realidad que el momento hay 658 asesinatos solo en el mes de enero que este paso Vamos a superar los 8000 y que la tasa va a subir considerablemente por eso yo quiero ser presidente para devolverle a usted Paul a sus hijos a su hermanos a sus familiares a las personas de la tercera edad ese país de paz que todos necesitan correcto dentro de sus planes qué le promete al público para que le dé su voto a ver yo no prometo yo son propuestas que hago que las voy a cumplir porque yo demagogo no soy demagogo es ofrecer y no cumplir Y peor aú traicionar jamás Paul soy un general de honor por eso llevo esta chaqueta que representa el espíritu y la esencia de Víctor araus un general de honor que cumple lo que dice entonces dentro de mi propuesta está dev volver integralmente integralmente la paz y la seguridad de los ciudadanos cómo le voy a hacer eso Paul ya lo he dicho públicamente le voy a quitar los derechos a los delincuentes De qué forma voy a tratar al delincuente tal cual como trata al ciudadano Paul si el ciudadano quita la vida a un a un ciudadano común se merece la vida es obligación del Estado Paul acabar con la vida del delincuente antes que el delincuente acabe con el ciudadano de bien pero aquí en nuestro país nadie le puede quitarle la vida a nadie nadie y los delincuentes Por qué le quitan la vida a ver yo no que le voy a quitar la vida Voy a someter al la pena de muerte porque yo voy a ser pero es complicado el tema de la pena de muerte en nuestro país hay que cambiar muchas cosas a ver Paul usted no se convierta con todo respeto amigo lo conocemos años no se convierta en una persona que busca un problema o una solución la solución la estoy planteando yo pues Paul si no nos cruzamos de brazo pa me explico entonces una solución para acabar con el sicariato y las violaciones es liberar al Ecuador porque no es que yo los voy a matar No es que la policía los va a matar pero delincuente armado que pong en riesgo la vida de un ciudadano la suya le esperará el cementerio porque la policía tendrá todo el respaldo y no tendrá miedo de darle bala al delincuente Entonces el tema de los los picaros y violaciones voy a luchar incansablemente para liberar al Ecuador de los tratados internacionales porque no soy insensato Pues yo no voy a exponer al país Paul a sanciones internacionales sanciones diplomáticas y una serie de situaciones que en vez de ayudar van a debilitar la imagen del país pero el momento que yo proponga a nivel de organismos internacionales liberar al Ecuador Para proponer la pena de muerte y esa pena de muerte sea bien aplicada Paul porque por ahí también aparece pero Cómo confiar e ...

# %%
resultados['metadatas'][0]
# Out:
# [{'candidato': 'Francesco Tabacchi',
#   'descripcion': 'Francesco Tabaqui, candidato presidencial por Creo, expone su visión para el país basada en seguridad, generación de empleo y apertura a la inversión privada en sectores estratégicos como energía, minería y petróleo. Propone una política de "mano dura, mano justa y mano inteligente", inspirada en el modelo de El Salvador, con la creación del Escuadrón de la Pacificación para combatir el crimen organizado. En economía, plantea incentivos fiscales para fomentar el empleo y la modernización del sector agropecuario con una "agricultura 4.0". Rechaza la idea de modificar la Constitución y en su lugar aboga por reformas rápidas para mejorar la seguridad y la economía. También sugiere concesionar la generación eléctrica e infraestructura vial, y se muestra abierto a revisar el sistema de subsidios. En política exterior, busca mantener relaciones pragmáticas con EE.UU., México y Venezuela, aunque sin reconocer a Nicolás Maduro. Destaca la importancia de la transparencia y asegura que su campaña se financia con recursos propios y redes sociales, enfatizando su historial como empresario y gobernador del Guayas.',
#   'temas_tratados': 'reforma constitucional, cambios legislativos, seguridad, crimen organizado, influencia del modelo de El Salvador, Escuadrón de la Pacificación, relación con la Asamblea Nacional, bloqueos legislativos, administración pública, compras del Estado (CERCOP), crisis del IESS, generación de empleo, incentivos fiscales para contratación, infraestructura, concesiones viales, crisis energética, inversión extranjera, política exterior, relaciones con México, relaciones con Venezuela, relaciones con EE.UU., subsidios de combustibles, tarifas eléctricas, financiamiento de campaña, transparencia patrimonial'},
#  {'candidato': 'Henry Cucalon',
#   'descripcion': 'Henry Cucalón, candidato presidencial de las elecciones de 2025, quien expone sus propuestas para el país, enfocándose en la liberalización de sectores como la minería y la energía, la simplificación de trámites y la reducción de la burocracia. Cucalón destaca la importancia de un estado austero y eficiente, criticando el populismo y la corrupción. También aborda temas clave como la seguridad, la reforma laboral, la creación de empleo y la modernización del sistema penitenciario, buscando un cambio radical hacia un gobierno más enfocado en la iniciativa privada y en políticas de largo plazo para el desarrollo económico.',
#   'temas_tratados': 'propuestas de inversión privada, sistema judicial, formalidad en la política, seguridad, empleo, minería, agricultura, turismo, austeridad fiscal, subsidios, generación de empleo, régimen laboral, reformas penitenciarias, reducción de burocracia'},
#  {'candidato': 'Victor Araus',
#   'descripcion': 'En esta entrevista, Víctor Araus presentó su visión sobre seguridad y justicia, reafirmando su propuesta de eliminar los derechos de los delincuentes y considerar la implementación de la pena de muerte mediante consulta popular. Señaló la necesidad de declarar una crisis carcelaria y tomar control de las cárceles, promoviendo la rehabilitación de presos mediante trabajo y educación obligatoria. Araus también enfatizó su compromiso de luchar contra la corrupción en la justicia y mejorar la seguridad pública. Además, destacó planes económicos como la reactivación de empleo y el combate a la evasión tributaria, posicionándose como el único candidato con un enfoque firme y disruptivo para devolver la paz al Ecuador.',
#   'temas_tratados': 'Seguridad y combate a la delincuencia, eliminación de derechos a los delincuentes, propuestas para implementar la pena de muerte, crisis carcelaria y control de las cárceles, trabajo y educación obligatoria para presos, consulta popular para reformas legales, migración y deportación de extranjeros ilegales, reactivación económica, generación de empleo, combate a la evasión tributaria, corrupción en el sistema judicial, liderazgo en la seguridad pública.'}]
